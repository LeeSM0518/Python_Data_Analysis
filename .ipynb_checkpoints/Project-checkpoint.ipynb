# %%
import pandas as pd

# %%
Daejoen = pd.read_csv('./daejoen.csv', encoding = 'UTF-8')
Daejoen.head(30)
# Out:
#                       타임스탬프 귀하의 성별은 무엇입니까? 귀하의 나이는 어떻게 되십니까? 귀하의 직업은 무엇입니까?  \
# 0   2018. 12. 2 오후 11:06:08             남자               20대            대학생
# 1   2018. 12. 2 오후 11:06:49             남자               20대            대학생
# 2   2018. 12. 2 오후 11:08:36             여자               20대            대학생
# 3   2018. 12. 2 오후 11:09:01             여자               20대            대학생
# 4   2018. 12. 2 오후 11:12:38             남자               20대            대학생
# 5   2018. 12. 2 오후 11:14:13             남자               30대            공무원
# 6   2018. 12. 2 오후 11:14:28             남자               20대            대학생
# 7   2018. 12. 2 오후 11:15:03             여자               20대            대학생
# 8   2018. 12. 2 오후 11:15:37             남자               20대             기타
# 9   2018. 12. 2 오후 11:15:54             여자               20대             기타
# 10  2018. 12. 2 오후 11:16:26             남자               20대             기타
# 11  2018. 12. 2 오후 11:16:59             남자               20대            대학생
# 12  2018. 12. 2 오후 11:17:41             남자               20대            대학생
# 13  2018. 12. 2 오후 11:18:39             여자               20대            대학생
# 14  2018. 12. 2 오후 11:25:58             남자               30대       중 · 고등학생
# 15  2018. 12. 2 오후 11:26:24             여자               20대            대학생
# 16  2018. 12. 2 오후 11:27:40             남자               20대            대학생
# 17  2018. 12. 2 오후 11:28:58             여자               20대            대학생
# 18  2018. 12. 2 오후 11:29:28             여자               20대            대학생
# 19  2018. 12. 2 오후 11:30:07             남자               30대            회사원
# 20  2018. 12. 3 오전 12:01:14             남자               20대            회사원
#
#    귀하는 대전에 거주하십니까? 거주지역 보다 대전에서 더 많은 시간을 보내십니까?  \
# 0                예                          NaN
# 1                예                          NaN
# 2                예                          NaN
# 3              아니요                            예
# 4                예                          NaN
# 5                예                          NaN
# 6              아니요                          아니요
# 7                예                          NaN
# 8                예                          NaN
# 9              아니요                          아니요
# 10               예                          NaN
# 11               예                          NaN
# 12               예                          NaN
# 13               예                          NaN
# 14               예                          NaN
# 15               예                          NaN
# 16               예                          NaN
# 17               예                          NaN
# 18               예                          NaN
# 19               예                          NaN
# 20               예                          NaN
#
#     귀하께서는 일주일에 버스를 얼마나 자주 이용하십니까? 버스를 이용하는데 어느정도 만족하십니까?  \
# 0                             4.0                    불만족
# 1                             2.0                     보통
# 2                             4.0                    불만족
# 3                             NaN                    NaN
# 4                             1.0                    불만족
# 5                             3.0                     만족
# 6                             NaN                    NaN
# 7                             3.0                     만족
# 8                             4.0                     만족
# 9                             NaN                    NaN
# 10                            2.0                     만족
# 11                            2.0                    불만족
# 12                            4.0                  매우 만족
# 13                            5.0                    불만족
# 14                            2.0                     보통
# 15                            3.0                     만족
# 16                            2.0                    불만족
# 17                            2.0                     만족
# 18                            3.0                     만족
# 19                            4.0                    불만족
# 20                            4.0                     보통
#
#     귀하께서는 일주일에 지하철을 얼마나 자주 이용하십니까? 지하철을 이용하는데 어느정도 만족하십니까?  \
# 0                              3.0                      보통
# 1                              3.0                      보통
# 2                              3.0                      보통
# 3                              NaN                     NaN
# 4                              2.0                     불만족
# 5                              3.0                  매우 불만족
# 6                              NaN                     NaN
# 7                              4.0                     불만족
# 8                              4.0                   매우 만족
# 9                              NaN                     NaN
# 10                             4.0                      보통
# 11                             4.0                      보통
# 12                             5.0                   매우 만족
# 13                             3.0                     불만족
# 14                             4.0                     불만족
# 15                             4.0                      만족
# 16                             4.0                     불만족
# 17                             4.0                      보통
# 18                             2.0                     불만족
# 19                             4.0                     불만족
# 20                             4.0                     불만족
#
#                  ...                귀하께서는 한 달에 기차를 얼마나 자주 이용하십니까?  \
# 0                ...                                          NaN
# 1                ...                                          NaN
# 2                ...                                          1.0
# 3                ...                                          NaN
# 4                ...                                          1.0
# 5                ...                                          NaN
# 6                ...                                          NaN
# 7                ...                                          NaN
# 8                ...                                          2.0
# 9                ...                                          NaN
# 10               ...                                          NaN
# 11               ...                                          2.0
# 12               ...                                          2.0
# 13               ...                                          4.0
# 14               ...                                          4.0
# 15               ...                                          2.0
# 16               ...                                          4.0
# 17               ...                                          NaN
# 18               ...                                          NaN
# 19               ...                                          1.0
# 20               ...                                          3.0
#
#    기차를 이용하는데 어느정도 만족하십니까?  자차 및 가족 차를 운전하고 다니시나요?  \
# 0                     NaN                운전하지 않는다
# 1                     NaN                운전하지 않는다
# 2                      보통                운전하지 않는다
# 3                     NaN                     NaN
# 4                      보통                    운전한다
# 5                     NaN                운전하지 않는다
# 6                     NaN                     NaN
# 7                     NaN                운전하지 않는다
# 8                      보통                운전하지 않는다
# 9                     NaN                     NaN
# 10                    NaN                운전하지 않는다
# 11                     만족                운전하지 않는다
# 12                     보통                운전하지 않는다
# 13                    불만족                운전하지 않는다
# 14                     보통                운전하지 않는다
# 15                    불만족                운전하지 않는다
# 16                     보통                운전하지 않는다
# 17                    NaN                운전하지 않는다
# 18                    NaN                운전하지 않는다
# 19                     보통                운전하지 않는다
# 20                     만족                운전하지 않는다
#
#    자차 및 가족 차를 이용하는데 어느정도 만족하십니까? 버스를 이용하는데 불만족 하시는 이유는 무엇입니까?  \
# 0                            NaN           버스들의 노선들이 너무 한정적이다
# 1                            NaN                          NaN
# 2                            NaN                 배차 간격이 너무 길다
# 3                            NaN                          NaN
# 4                            불만족           버스들의 노선들이 너무 한정적이다
# 5                            NaN                          NaN
# 6                            NaN                          NaN
# 7                            NaN                          NaN
# 8                            NaN                          NaN
# 9                            NaN                          NaN
# 10                           NaN                          NaN
# 11                           NaN                  버스가 너무 혼잡하다
# 12                           NaN                          NaN
# 13                           NaN           버스들의 노선들이 너무 한정적이다
# 14                           NaN                          NaN
# 15                           NaN                          NaN
# 16                           NaN           버스들의 노선들이 너무 한정적이다
# 17                           NaN                          NaN
# 18                           NaN                          NaN
# 19                           NaN            버스 정류장의 갯수가 너무 적다
# 20                           NaN                          NaN
#
#    지하철을 이용하는데 불만족 하시는 이유는 무엇입니까? 고속 및 시외 버스 이용하는데 불만족 하시는 이유는 무엇입니까?  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                      노선이 부족하다.                                 NaN
# 5                      노선이 부족하다.                                 NaN
# 6                            NaN                                 NaN
# 7                   배차 간격이 너무 길다                                 NaN
# 8                            NaN                                 NaN
# 9                            NaN                                 NaN
# 10                           NaN                                 NaN
# 11                           NaN                                 NaN
# 12                           NaN                                 NaN
# 13              역의 시설이 별로 좋지 않다.                                 NaN
# 14                  배차 간격이 너무 길다                                 NaN
# 15                           NaN                                 NaN
# 16                  배차 간격이 너무 길다                                 NaN
# 17                           NaN                                 NaN
# 18                     노선이 부족하다.                                 NaN
# 19              역의 시설이 별로 좋지 않다.                                 NaN
# 20              역의 시설이 별로 좋지 않다.                                 NaN
#
#    기차를 이용하는데 불만족 하시는 이유는 무엇입니까?  자차 및 가족 차를 이용하는데 불만족 하시는 이유는 무엇입니까?  \
# 0            대전에 기차역의 개수가 너무 적다                                  NaN
# 1            대전에 기차역의 개수가 너무 적다                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                                  NaN
# 4                           NaN                          주차 공간이 부족하다
# 5                  직원이 너무 불친절하다                                  NaN
# 6                           NaN                                  NaN
# 7            대전에 기차역의 개수가 너무 적다                                  NaN
# 8                           NaN                                  NaN
# 9                           NaN                                  NaN
# 10                 직원이 너무 불친절하다                                  NaN
# 11                          NaN                                  NaN
# 12                          NaN                                  NaN
# 13                 직원이 너무 불친절하다                                  NaN
# 14                          NaN                                  NaN
# 15           대전에 기차역의 개수가 너무 적다                                  NaN
# 16                          NaN                                  NaN
# 17                 직원이 너무 불친절하다                                  NaN
# 18                 배차 간격이 너무 길다                                  NaN
# 19                          NaN                                  NaN
# 20                          NaN                                  NaN
#
#    대전의 교통 수단에 대해 대체적으로 얼마나 만족하십니까?
# 0                              2.0
# 1                              2.0
# 2                              3.0
# 3                              4.0
# 4                              2.0
# 5                              2.0
# 6                              NaN
# 7                              2.0
# 8                              4.0
# 9                              NaN
# 10                             4.0
# 11                             3.0
# 12                             3.0
# 13                             4.0
# 14                             2.0
# 15                             3.0
# 16                             4.0
# 17                             3.0
# 18                             4.0
# 19                             2.0
# 20                             4.0
#
# [21 rows x 22 columns]

# %%
Daejoen.columns
# Out:
# Index(['타임스탬프', '귀하의 성별은 무엇입니까?', '귀하의 나이는 어떻게 되십니까?', '귀하의 직업은 무엇입니까?',
#        '귀하는 대전에 거주하십니까?', '거주지역 보다 대전에서 더 많은 시간을 보내십니까?',
#        '귀하께서는 일주일에 버스를 얼마나 자주 이용하십니까?', '버스를 이용하는데 어느정도 만족하십니까?',
#        '귀하께서는 일주일에 지하철을 얼마나 자주 이용하십니까?', '지하철을 이용하는데 어느정도 만족하십니까?',
#        '귀하께서는 한 달에 고속 및 시외 버스를 얼마나 자주 이용하십니까?',
#        '고속 및 시외 버스를 이용하는데 어느정도 만족하십니까?', '귀하께서는 한 달에 기차를 얼마나 자주 이용하십니까?',
#        '기차를 이용하는데 어느정도 만족하십니까?', '자차 및 가족 차를 운전하고 다니시나요?',
#        '자차 및 가족 차를 이용하는데 어느정도 만족하십니까?', '버스를 이용하는데 불만족 하시는 이유는 무엇입니까?',
#        '지하철을 이용하는데 불만족 하시는 이유는 무엇입니까?', '고속 및 시외 버스 이용하는데 불만족 하시는 이유는 무엇입니까?',
#        '기차를 이용하는데 불만족 하시는 이유는 무엇입니까?', '자차 및 가족 차를 이용하는데 불만족 하시는 이유는 무엇입니까?',
#        '대전의 교통 수단에 대해 대체적으로 얼마나 만족하십니까?'],
#       dtype='object')

# %%
len(Daejoen.columns)
# Out:
# 22

# %%
Daejoen.rename(columns = {
    Daejoen.columns[0] : "",
    Daejoen.columns[1] : '성별',
    Daejoen.columns[2] : '나이',
    Daejoen.columns[3] : '직업',
    Daejoen.columns[4] : '대전 거주?',
    Daejoen.columns[5] : '대전에서 더 생활?',
    Daejoen.columns[6] : '버스 자주 이용?',
    Daejoen.columns[7] : '버스 이용 만족?',
    Daejoen.columns[8] : '지하철 자주 이용?',
    Daejoen.columns[9] : '지하철 이용 만족?',
    Daejoen.columns[10] : '고속 및 시외 버스 자주 이용?',
    Daejoen.columns[11] : '고속 및 시외 버스 만족?',
    Daejoen.columns[12] : '기차 자주 이용?',
    Daejoen.columns[13] : '기차 만족?',
    Daejoen.columns[14] : '자차 이용?',
    Daejoen.columns[15] : '자차 만족?',
    Daejoen.columns[16] : '버스 불편?',
    Daejoen.columns[17] : '지하철 이용 불편?',
    Daejoen.columns[18] : '고속 및 시외 버스 불편?',
    Daejoen.columns[19] : '기차 불편?',
    Daejoen.columns[20] : '자차 불편?',
    Daejoen.columns[21] : '대전 교통 만족?'
}, inplace = True)
Daejoen.head()
# Out:
#                             성별   나이   직업 대전 거주? 대전에서 더 생활?  버스 자주 이용?  \
# 0  2018. 12. 2 오후 11:06:08  남자  20대  대학생      예        NaN        4.0
# 1  2018. 12. 2 오후 11:06:49  남자  20대  대학생      예        NaN        2.0
# 2  2018. 12. 2 오후 11:08:36  여자  20대  대학생      예        NaN        4.0
# 3  2018. 12. 2 오후 11:09:01  여자  20대  대학생    아니요          예        NaN
# 4  2018. 12. 2 오후 11:12:38  남자  20대  대학생      예        NaN        1.0
#
#   버스 이용 만족?  지하철 자주 이용? 지하철 이용 만족?    ...     기차 자주 이용? 기차 만족?    자차 이용?  \
# 0       불만족         3.0         보통    ...           NaN    NaN  운전하지 않는다
# 1        보통         3.0         보통    ...           NaN    NaN  운전하지 않는다
# 2       불만족         3.0         보통    ...           1.0     보통  운전하지 않는다
# 3       NaN         NaN        NaN    ...           NaN    NaN       NaN
# 4       불만족         2.0        불만족    ...           1.0     보통      운전한다
#
#   자차 만족?              버스 불편? 지하철 이용 불편? 고속 및 시외 버스 불편?              기차 불편?  \
# 0    NaN  버스들의 노선들이 너무 한정적이다        NaN            NaN  대전에 기차역의 개수가 너무 적다
# 1    NaN                 NaN        NaN            NaN  대전에 기차역의 개수가 너무 적다
# 2    NaN        배차 간격이 너무 길다        NaN            NaN                 NaN
# 3    NaN                 NaN        NaN            NaN                 NaN
# 4    불만족  버스들의 노선들이 너무 한정적이다  노선이 부족하다.            NaN                 NaN
#
#         자차 불편? 대전 교통 만족?
# 0          NaN       2.0
# 1          NaN       2.0
# 2          NaN       3.0
# 3          NaN       4.0
# 4  주차 공간이 부족하다       2.0
#
# [5 rows x 22 columns]

# %%
Daejoen
# Out:
#                              성별   나이        직업 대전 거주? 대전에서 더 생활?  버스 자주 이용?  \
# 0   2018. 12. 2 오후 11:06:08  남자  20대       대학생      예        NaN        4.0
# 1   2018. 12. 2 오후 11:06:49  남자  20대       대학생      예        NaN        2.0
# 2   2018. 12. 2 오후 11:08:36  여자  20대       대학생      예        NaN        4.0
# 3   2018. 12. 2 오후 11:09:01  여자  20대       대학생    아니요          예        NaN
# 4   2018. 12. 2 오후 11:12:38  남자  20대       대학생      예        NaN        1.0
# 5   2018. 12. 2 오후 11:14:13  남자  30대       공무원      예        NaN        3.0
# 6   2018. 12. 2 오후 11:14:28  남자  20대       대학생    아니요        아니요        NaN
# 7   2018. 12. 2 오후 11:15:03  여자  20대       대학생      예        NaN        3.0
# 8   2018. 12. 2 오후 11:15:37  남자  20대        기타      예        NaN        4.0
# 9   2018. 12. 2 오후 11:15:54  여자  20대        기타    아니요        아니요        NaN
# 10  2018. 12. 2 오후 11:16:26  남자  20대        기타      예        NaN        2.0
# 11  2018. 12. 2 오후 11:16:59  남자  20대       대학생      예        NaN        2.0
# 12  2018. 12. 2 오후 11:17:41  남자  20대       대학생      예        NaN        4.0
# 13  2018. 12. 2 오후 11:18:39  여자  20대       대학생      예        NaN        5.0
# 14  2018. 12. 2 오후 11:25:58  남자  30대  중 · 고등학생      예        NaN        2.0
# 15  2018. 12. 2 오후 11:26:24  여자  20대       대학생      예        NaN        3.0
# 16  2018. 12. 2 오후 11:27:40  남자  20대       대학생      예        NaN        2.0
# 17  2018. 12. 2 오후 11:28:58  여자  20대       대학생      예        NaN        2.0
# 18  2018. 12. 2 오후 11:29:28  여자  20대       대학생      예        NaN        3.0
# 19  2018. 12. 2 오후 11:30:07  남자  30대       회사원      예        NaN        4.0
# 20  2018. 12. 3 오전 12:01:14  남자  20대       회사원      예        NaN        4.0
#
#    버스 이용 만족?  지하철 자주 이용? 지하철 이용 만족?    ...     기차 자주 이용? 기차 만족?    자차 이용?  \
# 0        불만족         3.0         보통    ...           NaN    NaN  운전하지 않는다
# 1         보통         3.0         보통    ...           NaN    NaN  운전하지 않는다
# 2        불만족         3.0         보통    ...           1.0     보통  운전하지 않는다
# 3        NaN         NaN        NaN    ...           NaN    NaN       NaN
# 4        불만족         2.0        불만족    ...           1.0     보통      운전한다
# 5         만족         3.0     매우 불만족    ...           NaN    NaN  운전하지 않는다
# 6        NaN         NaN        NaN    ...           NaN    NaN       NaN
# 7         만족         4.0        불만족    ...           NaN    NaN  운전하지 않는다
# 8         만족         4.0      매우 만족    ...           2.0     보통  운전하지 않는다
# 9        NaN         NaN        NaN    ...           NaN    NaN       NaN
# 10        만족         4.0         보통    ...           NaN    NaN  운전하지 않는다
# 11       불만족         4.0         보통    ...           2.0     만족  운전하지 않는다
# 12     매우 만족         5.0      매우 만족    ...           2.0     보통  운전하지 않는다
# 13       불만족         3.0        불만족    ...           4.0    불만족  운전하지 않는다
# 14        보통         4.0        불만족    ...           4.0     보통  운전하지 않는다
# 15        만족         4.0         만족    ...           2.0    불만족  운전하지 않는다
# 16       불만족         4.0        불만족    ...           4.0     보통  운전하지 않는다
# 17        만족         4.0         보통    ...           NaN    NaN  운전하지 않는다
# 18        만족         2.0        불만족    ...           NaN    NaN  운전하지 않는다
# 19       불만족         4.0        불만족    ...           1.0     보통  운전하지 않는다
# 20        보통         4.0        불만족    ...           3.0     만족  운전하지 않는다
#
#    자차 만족?              버스 불편?        지하철 이용 불편? 고속 및 시외 버스 불편?  \
# 0     NaN  버스들의 노선들이 너무 한정적이다               NaN            NaN
# 1     NaN                 NaN               NaN            NaN
# 2     NaN        배차 간격이 너무 길다               NaN            NaN
# 3     NaN                 NaN               NaN            NaN
# 4     불만족  버스들의 노선들이 너무 한정적이다         노선이 부족하다.            NaN
# 5     NaN                 NaN         노선이 부족하다.            NaN
# 6     NaN                 NaN               NaN            NaN
# 7     NaN                 NaN      배차 간격이 너무 길다            NaN
# 8     NaN                 NaN               NaN            NaN
# 9     NaN                 NaN               NaN            NaN
# 10    NaN                 NaN               NaN            NaN
# 11    NaN         버스가 너무 혼잡하다               NaN            NaN
# 12    NaN                 NaN               NaN            NaN
# 13    NaN  버스들의 노선들이 너무 한정적이다  역의 시설이 별로 좋지 않다.            NaN
# 14    NaN                 NaN      배차 간격이 너무 길다            NaN
# 15    NaN                 NaN               NaN            NaN
# 16    NaN  버스들의 노선들이 너무 한정적이다      배차 간격이 너무 길다            NaN
# 17    NaN                 NaN               NaN            NaN
# 18    NaN                 NaN         노선이 부족하다.            NaN
# 19    NaN   버스 정류장의 갯수가 너무 적다  역의 시설이 별로 좋지 않다.            NaN
# 20    NaN                 NaN  역의 시설이 별로 좋지 않다.            NaN
#
#                 기차 불편?       자차 불편? 대전 교통 만족?
# 0   대전에 기차역의 개수가 너무 적다          NaN       2.0
# 1   대전에 기차역의 개수가 너무 적다          NaN       2.0
# 2                  NaN          NaN       3.0
# 3                  NaN          NaN       4.0
# 4                  NaN  주차 공간이 부족하다       2.0
# 5         직원이 너무 불친절하다          NaN       2.0
# 6                  NaN          NaN       NaN
# 7   대전에 기차역의 개수가 너무 적다          NaN       2.0
# 8                  NaN          NaN       4.0
# 9                  NaN          NaN       NaN
# 10        직원이 너무 불친절하다          NaN       4.0
# 11                 NaN          NaN       3.0
# 12                 NaN          NaN       3.0
# 13        직원이 너무 불친절하다          NaN       4.0
# 14                 NaN          NaN       2.0
# 15  대전에 기차역의 개수가 너무 적다          NaN       3.0
# 16                 NaN          NaN       4.0
# 17        직원이 너무 불친절하다          NaN       3.0
# 18        배차 간격이 너무 길다          NaN       4.0
# 19                 NaN          NaN       2.0
# 20                 NaN          NaN       4.0
#
# [21 rows x 22 columns]

# %%
Daejoen.set_index('나이', inplace = True)

# %%
Daejoen.head()
# Out:
#                               성별   직업 대전 거주? 대전에서 더 생활?  버스 자주 이용? 버스 이용 만족?  \
# 나이
# 20대  2018. 12. 2 오후 11:06:08  남자  대학생      예        NaN        4.0       불만족
# 20대  2018. 12. 2 오후 11:06:49  남자  대학생      예        NaN        2.0        보통
# 20대  2018. 12. 2 오후 11:08:36  여자  대학생      예        NaN        4.0       불만족
# 20대  2018. 12. 2 오후 11:09:01  여자  대학생    아니요          예        NaN       NaN
# 20대  2018. 12. 2 오후 11:12:38  남자  대학생      예        NaN        1.0       불만족
#
#      지하철 자주 이용? 지하철 이용 만족?  고속 및 시외 버스 자주 이용?    ...    기차 자주 이용?  기차 만족?  \
# 나이                                               ...
# 20대         3.0         보통                3.0    ...          NaN     NaN
# 20대         3.0         보통                2.0    ...          NaN     NaN
# 20대         3.0         보통                2.0    ...          1.0      보통
# 20대         NaN        NaN                NaN    ...          NaN     NaN
# 20대         2.0        불만족                1.0    ...          1.0      보통
#
#        자차 이용? 자차 만족?              버스 불편? 지하철 이용 불편? 고속 및 시외 버스 불편?  \
# 나이
# 20대  운전하지 않는다    NaN  버스들의 노선들이 너무 한정적이다        NaN            NaN
# 20대  운전하지 않는다    NaN                 NaN        NaN            NaN
# 20대  운전하지 않는다    NaN        배차 간격이 너무 길다        NaN            NaN
# 20대       NaN    NaN                 NaN        NaN            NaN
# 20대      운전한다    불만족  버스들의 노선들이 너무 한정적이다  노선이 부족하다.            NaN
#
#                  기차 불편?       자차 불편? 대전 교통 만족?
# 나이
# 20대  대전에 기차역의 개수가 너무 적다          NaN       2.0
# 20대  대전에 기차역의 개수가 너무 적다          NaN       2.0
# 20대                 NaN          NaN       3.0
# 20대                 NaN          NaN       4.0
# 20대                 NaN  주차 공간이 부족하다       2.0
#
# [5 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
Daejoen['성별'].plot(kind='barh', grid = True, figsize=(10, 10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f42757ae271d> in <module>
# ----> 1 Daejoen['성별'].plot(kind='barh', grid = True, figsize=(10, 10))
#       2 plt.show()
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
Daejoen = pd.read_csv('./Daejoen.csv', encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-b9dc38cb051a> in <module>
# ----> 1 Daejoen = pd.read_csv('./Daejoenw.csv', encoding = 'utf-8')
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'./Daejoenw.csv' does not exist
