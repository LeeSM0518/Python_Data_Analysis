# %%
from bs4 import BeautifulSoup

# %%
# html 파일 불러서 읽는다
page = open('./DataScience/data/03. test_first.html','r').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
# children 태그 리스트 불러오기
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
# html 2번째 태그에 접속
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
# 미리 저장해둔 html 에서 한 단계 아래 태그를 불러온다
list(html.children)
# Out:
# ['\n', <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>, '\n', <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>, '\n']

# %%
# html의 3번째 인덱스 확인,
# html의 본문(body) 부분을 추출한다.

body = list(html.children)[3]
print(body.prettify)
# Out:
# <bound method Tag.prettify of <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>>

# %%
# soup 안에 있는 body를 출력시킨다

soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# body 아래의 리스트 확인

list(body.children)
# Out:
# ['\n', <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>, '\n', <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, '\n', <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>, '\n']

# %%
# 태그를 찾아주는 find_all 메소드를 사용하여 'p' 태그를 찾을 수 있다

soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>, <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>, <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
# find 메소드를 사용하여 맨 첫 번째 'p' 태그를 불러옴

soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# 클래스의 outer text를 모두 찾는다

soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
# class outer text 만 찾을 수도 있다

soup.find_all( class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
# id 가 first 인 것을 찾음

soup.find_all(id='first')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
# soup의 헤드를 가져옴

soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
# next_sibling

soup.head.next_sibling
# Out:
# '\n'

# %%
# body 부분만 추출

soup.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# body의 p를 가져온다

body.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# 다음 , 다음 태그로 이동

body.p.next_sibling.next_sibling
# Out:
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>

# %%
# p 태그의 text를 가져온다

for each_tag in soup.find_all('p'):
    print(each_tag.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
# body 의 택스트 부분 추출

body.get_text()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
# soup 에서 a 태그를 찾아서 출력

links = soup.find_all('a')
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
# links의 'href'을 키 값으로 넣어서 href에 저장 후
# href의 링크 추출

for each in links:
    href = each['href']
    text = each.string
    print(text + '->' + href)
# Out:
# PinkWink->http://www.pinkwink.kr
# Python->https://www.python.org

# %%
# 크롬 개발자 도구 이용

from urllib.request import urlopen, urljoin

# %%
# 네이버 금융 페이지의 html을 불러옴

url = "https://finance.naver.com/marketindex/"
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <script language="javascript" src="https://finance.naver.com/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <script language="JavaScript" src="/js/flashObject.js?20181129154824">
#  </script>
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#         <h3 class="h_lst">
# ...

# %%
# span의 value 값을 가져온다.

soup.find_all('span', 'value')[0].string
# Out:
# '1,130.00'

# %%
# 시카고 맛집 사이트에 접속
# url로 태그를 합치고
# html에 url에 저장한 페이지의 html을 저장

from bs4 import BeautifulSoup
from urllib.request import urlopen

url_base = "http://www.chicagomag.com"
url_sub = '/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'
url = url_base + url_sub

html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   The 50 Best Sandwiches in Chicago |
#   Chicago magazine
#       |  November 2012
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="Our list of Chicago’s 50 best sandwiches, ranked in order of deliciousness" name="description"/>
# <!-- <meta name="description" content="Our list of Chicago’s 50 best sandwiches, ranked in order of deliciousness"> -->
# <meta content="sandwiches, dining" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# ...

# %%
# div 태그의 sammy 태그를 찾는다.
print(soup.find_all('div', 'sammy'))
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">3</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
# Xoco<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">4</div>
# ...

# %%
# sammy 태그의 리스트 길이
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
# div의 sammy 클래스의 첫 번째 값을 확인해보면
# BLT 라는 이름을 페이지에서 확인할 수 있습니다.
print(soup.find_all('div', 'sammy')[0])
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>

# %%
# tmp 에 방금 찾은 값 저장
tmp_one = soup.find_all('div', 'sammy')[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
# find를 통해 sammyRank 클래스 확인
tmp_one.find(class_='sammyRank')
# Out:
# <div class="sammyRank">1</div>

# %%
# 택스트 출력
tmp_one.find(class_='sammyRank').get_text()
# Out:
# '1'

# %%
# sammyListing에서 택스트 가져옴
tmp_one.find(class_='sammyListing').get_text()
# Out:
# 'BLT\r\nOld Oak Tap\nRead more '

# %%
# a 태그의 href를 확인해보면
# url을 확인할 수 있다.
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
import re  # 정규표현식 모듈

# sammyListing 을 불러와서 줄바꿈 등으로 끊어서 저장
tmp_string = tmp_one.find(class_='sammyListing').get_text()
re.split(('\n|\r\n'), tmp_string)

# 끊어서 저장한 값 불러오기
print(re.split(('\n|\r\n'), tmp_string)[0])
print(re.split(('\n|\r\n'), tmp_string)[1])
# Out:
# BLT
# Old Oak Tap

# %%
from urllib.parse import urljoin

rank = []
main_menu = []
cafe_name = []
url_add = []

# sammy 를 찾아 list_soup 에 저장
list_soup = soup.find_all('div', 'sammy')

for item in list_soup:
    # rank에는 세미렝크 저장
    rank.append(item.find(class_='sammyRank').get_text())
    
    tmp_string = item.find(class_='sammyListing').get_text()
    
    main_menu.append(re.split(('\n|\r\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n|\r\n'), tmp_string)[1])
    
    # a 태그를 찾아서 href를 url에 저장
    url_add.append(urljoin(url_base, item.find('a')['href']))

# %%
rank[:5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
main_menu[:5]
# Out:
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %%
url_add[:5]
# Out:
# ['http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
len(rank), len(main_menu), len(cafe_name), len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

# 아래와 같은 컬럼으로 데이터를 표로 만든다
data = {'Rank':rank, 'Menu':main_menu, 'Cafe':cafe_name, 'URL':url_add}
df = pd.DataFrame(data)
df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
# 컬럼 순서들을 변경
df = pd.DataFrame(data, columns=['Rank', 'Cafe', 'Menu', 'URL'])
df.head(5)
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df.to_csv('./DataScience/data/03. best_sandwiches_list_chicago.csv', sep=',',
         encoding = 'UTF-8')

# %%
df['URL'][0]
# Out:
# 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
html = urlopen(df['URL'][0])
soup_tmp = BeautifulSoup(html, 'html.parser')
soup_tmp
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   1. Old Oak Tap BLT |
#   Chicago magazine
#       |  November 2012
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="“Truly inspired.”" name="description"/>
# <!-- <meta name="description" content="&#8220;Truly inspired.&#8221;"> -->
# <meta content="" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//media.chicagomag.com" rel="dns-prefetch"/>
# <link href="//ox-d.godengo.com/" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
print(soup_tmp.find('p', 'addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import parser

import pandas as pd

# %%
df = pd.read_csv('./DataScience/data/03. best_sandwiches_list_chicago.csv',
                index_col = 0)
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df['URL'][0]
# Out:
# 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
html = urlopen(df['URL'][0])
soup_tmp = BeautifulSoup(html, 'html.parser')
soup_tmp
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   1. Old Oak Tap BLT |
#   Chicago magazine
#       |  November 2012
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="“Truly inspired.”" name="description"/>
# <!-- <meta name="description" content="&#8220;Truly inspired.&#8221;"> -->
# <meta content="" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//media.chicagomag.com" rel="dns-prefetch"/>
# <link href="//ox-d.godengo.com/" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
print(soup_tmp.find('p','addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
# 주소, 가격 가져온다
price_tmp = soup_tmp.find('p', 'addy').get_text()
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
# 빈칸으로 스플릿 한다
price_tmp.split()
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
price_tmp.split()[0]
# Out:
# '$10.'

# %%
# . 을 빼고 출력
price_tmp.split()[0][:-1]
# Out:
# '$10'

# %%
# 빈칸을 기준으로 합친다
' '.join(price_tmp.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %%
# price 와 address를 URL에서 스플릿하여 가져온다
from tqdm import tqdm_notebook

price = []
address = []

for n in df.index[:3]:
    html = urlopen(df['URL'][n])
    soup_tmp = BeautifulSoup(html, 'lxml')
    
    gettings = soup_tmp.find('p','addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))

# %%
price
# Out:
# ['$10', '$9', '$9.50']

# %%
address
# Out:
# ['2109 W. Chicago Ave.,', '800 W. Randolph St.,', '445 N. Clark St.,']

# %%
len(price), len(address), len(df)
# Out:
# (3, 3, 50)

# %%
from tqdm import tqdm_notebook

price = []
address = []
for n in tqdm_notebook(df.index):
    html = urlopen(df['URL'][n])
    sout_tmp = BeautifulSoup(html, 'lxml')
    
    gettings = sout_tmp.find('p', 'addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))

# %%
price
# Out:
# ['$10',
#  '$9',
#  '$9.50',
#  '$9.40',
#  '$10',
#  '$7.25',
#  '$16',
#  '$10',
#  '$9',
#  '$17',
#  '$11',
#  '$5.49',
#  '$14',
#  '$10',
#  '$13',
#  '$4.50',
#  '$11.95',
#  '$11.50',
#  '$6.25',
#  '$15',
#  '$5',
#  '$6',
#  '$8',
#  '$5.99',
#  '$7.52',
#  '$11.95',
#  '$7.50',
#  '$12.95',
#  '$7',
#  '$21',
#  '$9.79',
#  '$9.75',
#  '$13',
#  '$7.95',
#  '$9',
#  '$9',
#  '$8',
#  '$8',
#  '$7',
#  '$6',
#  '$7.25',
#  '$11',
#  '$6',
#  '$9',
#  '$5.49',
#  '$8',
#  '$6.50',
#  '$7.50',
#  '$8.75',
#  '$6.85']

# %%
address
# Out:
# ['2109 W. Chicago Ave.,',
#  '800 W. Randolph St.,',
#  '445 N. Clark St.,',
#  '914 Noyes St., Evanston,',
#  '825 W. Fulton Mkt.,',
#  '100 E. Walton',
#  '1639 S. Wabash Ave.,',
#  '2211 W. North Ave.,',
#  '3619 W. North Ave.,',
#  '3267 S. Halsted St.,',
#  '2537 N. Kedzie Blvd.,',
#  'Multiple',
#  '3124 N. Broadway,',
#  '3455 N. Southport Ave.,',
#  '2657 N. Kedzie Ave.,',
#  '1120 W. Grand Ave.,',
#  '1141 S. Jefferson St.,',
#  '333 E. Benton Pl.,',
#  '1411 N. Wells St.,',
#  '1747 N. Damen Ave.,',
#  '3209 W. Irving Park',
#  'Multiple',
#  '5347 N. Clark St.,',
#  '2954 W. Irving Park Rd.,',
#  'Multiple',
#  '191 Skokie Valley Rd., Highland Park,',
#  'Multiple',
#  '1818 W. Wilson Ave.,',
#  '2517 W. Division St.,',
#  '218 W. Kinzie',
#  'Multiple',
#  '1547 N. Wells St.,',
#  '415 N. Milwaukee Ave.,',
#  '1840 N. Damen Ave.,',
#  '1220 W. Webster Ave.,',
#  '5357 N. Ashland Ave.,',
#  '1834 W. Montrose Ave.,',
#  '615 N. State St.,',
#  'Multiple',
# ...

# %%
len(address)
# Out:
# 50

# %%
# 
df['Price'] = price
df['Address'] = address

df = df.loc[:,['Rank','Cafe','Menu','Price','Address']]
df.set_index('Rank',inplace=True)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
df.to_csv('./DataScience/data/03. best_sandwiches_list_chicago2.csv',
         sep=',', encoding='UTF-8')

# %%
import folium
import pandas as pd
import googlemaps
import numpy as np

# %%
df2 = pd.read_csv('./DataScience/data/03. best_sandwiches_list_chicago2.csv')
df2.head()
# Out:
#    Rank                    Cafe               Menu  Price  \
# 0     1             Old Oak Tap                BLT    $10
# 1     2               Au Cheval      Fried Bologna     $9
# 2     3                    Xoco  Woodland Mushroom  $9.50
# 3     4               Al’s Deli         Roast Beef  $9.40
# 4     5  Publican Quality Meats               PB&L    $10
#
#                     Address
# 0     2109 W. Chicago Ave.,
# 1      800 W. Randolph St.,
# 2         445 N. Clark St.,
# 3  914 Noyes St., Evanston,
# 4       825 W. Fulton Mkt.,

# %%
df = pd.read_csv('./DataScience/data/03. best_sandwiches_list_chicago2.csv',
         index_col = 0)
df.head(5)
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
gmaps_key = "AIzaSyCw1xenAZgH_LIaEHMWxVRdbTfkAE3CZ90"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
lat = []
lng = []

for n in tqdm_notebook(df.index):
    if df['Address'][n] != 'Multiple':
        target_name = df['Address'][n]+', ' +'Cicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
        
    else:
        lat.append(np.nan)
        lng.append(np.nan)

# %%
df['lat'] = lat
df['lng'] = lng

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()],
                    zoom_start=11)
mapping = folium.Marker([df['lat'].mean(), df['lng'].mean()],
                        popup='center').add_to(mapping)
mapping

# %%
import folium
import pandas as pd
import googlemaps
import numpy as np

# %%
df = pd.read_csv('./DataScience/data/03. best_sandwiches_list_chicago2.csv', index_col = 0)
df.head(5)
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
test = gmaps.geocode('800 W. Randolph St.,')
test[0]['geometry']
# Out:
# {'location': {'lat': 41.8846582, 'lng': -87.6476668},
#  'location_type': 'ROOFTOP',
#  'viewport': {'northeast': {'lat': 41.88600718029149,
#    'lng': -87.64631781970849},
#   'southwest': {'lat': 41.88330921970849, 'lng': -87.6490157802915}}}

# %%
test = gmaps.geocode('800 W. Randolph St., Chicago')
test[0]['geometry']
# Out:
# {'location': {'lat': 41.8846582, 'lng': -87.6476668},
#  'location_type': 'ROOFTOP',
#  'viewport': {'northeast': {'lat': 41.88600718029149,
#    'lng': -87.64631781970849},
#   'southwest': {'lat': 41.88330921970849, 'lng': -87.6490157802915}}}

# %%
gmaps_key = 'AIzaSyCw1xenAZgH_LIaEHMWxVRdbTfkAE3CZ90'
gmaps = googlemaps.Client(key = gmaps_key)

# %%
# 타겟 네임에 가게 주소를 저장하고
# 그 가게 주소의 위치를 가져온뒤
# 위도 경도에 저장
lat = []
lng = []

for n in tqdm_notebook(df.index):
    if df['Address'][n] != 'Multiple':
        target_name = df['Address'][n]+', '+'Chicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
        
    else:
        lat.append(np.nan)
        lng.append(np.nan)

# %%
len(lat)
# Out:
# 50

# %%
df['lat'] = lat
df['lng'] = lng

# %%
mapping = folium.Map(location = [df['lat'].mean(), df['lng'].mean()],
                    zoom_start=11)
folium.Marker([df['lat'].mean(), df['lng'].mean()],
             popup = 'center').add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from urllib.request import urlopen

# 길기 때문에 url을 파싱하여 저장
url_base = "http://movie.naver.com/"
url_syb = "movie/sdb/rank/rmovie.nhn?sel=cur&date=20181224"

# url을 합쳐서 url을 불러온다.
page = urlopen(url_base+url_syb)


soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20181224" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
# div 태그의 타이틀을 가져온다.
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=144906" title="베일리 어게인">베일리 어게인</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=156464" title="보헤미안 랩소디">보헤미안 랩소디</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=92125" title="헌터 킬러">헌터 킬러</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=178434" title="폴란드로 간 아이들">폴란드로 간 아이들</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=19099" title="트루먼 쇼">트루먼 쇼</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=31013" title="빌리 엘리어트">빌리 엘리어트</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=10001" title="시네마 천국">시네마 천국</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=144379" title="러빙 빈센트">러빙 빈센트</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=171725" title="스파이더맨: 뉴 유니버스">스파이더맨: 뉴 유니버스</a>
#  </div>, <div class="tit5">
# ...

# %%
# 첫 번째 값만 가져온다
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '베일리 어게인'

# %%
# 첫 번째 값의 평점
soup.find_all('td', 'point')[0].string
# Out:
# '9.55'

# %%
soup.find_all('td', 'point')
# Out:
# [<td class="point">9.55</td>,
#  <td class="point">9.51</td>,
#  <td class="point">9.46</td>,
#  <td class="point">9.42</td>,
#  <td class="point">9.32</td>,
#  <td class="point">9.29</td>,
#  <td class="point">9.28</td>,
#  <td class="point">9.20</td>,
#  <td class="point">9.18</td>,
#  <td class="point">9.16</td>,
#  <td class="point">9.16</td>,
#  <td class="point">9.13</td>,
#  <td class="point">9.10</td>,
#  <td class="point">9.09</td>,
#  <td class="point">9.06</td>,
#  <td class="point">9.00</td>,
#  <td class="point">8.99</td>,
#  <td class="point">8.98</td>,
#  <td class="point">8.88</td>,
#  <td class="point">8.81</td>,
#  <td class="point">8.70</td>,
#  <td class="point">8.69</td>,
#  <td class="point">8.63</td>,
#  <td class="point">8.59</td>,
#  <td class="point">8.58</td>,
#  <td class="point">8.52</td>,
#  <td class="point">8.52</td>,
#  <td class="point">8.48</td>,
#  <td class="point">8.38</td>,
#  <td class="point">8.31</td>,
#  <td class="point">8.28</td>,
# ...

# %%
movie_name = [soup.find_all('div', 'tit5')[n].a.string for n in range(0, 44)]
movie_name
# Out:
# ['베일리 어게인',
#  '보헤미안 랩소디',
#  '헌터 킬러',
#  '폴란드로 간 아이들',
#  '트루먼 쇼',
#  '빌리 엘리어트',
#  '시네마 천국',
#  '러빙 빈센트',
#  '스파이더맨: 뉴 유니버스',
#  '바울',
#  '스타 이즈 본',
#  '타샤 튜더',
#  '히트',
#  '로마',
#  '카메라를 멈추면 안 돼!',
#  '어거스트 러쉬',
#  '진링의 13소녀',
#  '러브 액츄얼리',
#  '소공녀',
#  '출국',
#  '완벽한 타인',
#  '브로크백 마운틴',
#  '거미줄에 걸린 소녀',
#  '라라랜드',
#  '스윙키즈',
#  '7년-그들이 없는 언론',
#  '아쿠아맨',
#  '그린치',
#  '팬텀 스레드',
#  '패터슨',
#  '국가부도의 날',
#  '부탁 하나만 들어줘',
#  '트와일라잇',
#  '런닝맨 : 풀룰루의 역습',
#  '성난황소',
#  '점박이 : 한반도의 공룡3D',
#  '호두까기 인형과 4개의 왕국',
#  '마약왕',
#  '도어락',
#  '나쁜 나라',
#  '모털 엔진',
#  '두 개의 문',
#  '리벤져',
#  '천안함 프로젝트']

# %%
movie_name = [soup.find_all('td', 'point')[n].string for n in range(0, 44)]
movie_name
# Out:
# ['9.55',
#  '9.51',
#  '9.46',
#  '9.42',
#  '9.32',
#  '9.29',
#  '9.28',
#  '9.20',
#  '9.18',
#  '9.16',
#  '9.16',
#  '9.13',
#  '9.10',
#  '9.09',
#  '9.06',
#  '9.00',
#  '8.99',
#  '8.98',
#  '8.88',
#  '8.81',
#  '8.70',
#  '8.69',
#  '8.63',
#  '8.59',
#  '8.58',
#  '8.52',
#  '8.52',
#  '8.48',
#  '8.38',
#  '8.31',
#  '8.28',
#  '8.05',
#  '7.87',
#  '7.79',
#  '7.67',
#  '7.63',
#  '7.44',
#  '6.98',
#  '6.82',
#  '6.49',
#  '6.45',
#  '5.15',
#  '5.11',
#  '4.33']

# %%
date = pd.date_range('2018-12-1', periods=100, freq='D')
date
# Out:
# DatetimeIndex(['2018-12-01', '2018-12-02', '2018-12-03', '2018-12-04',
#                '2018-12-05', '2018-12-06', '2018-12-07', '2018-12-08',
#                '2018-12-09', '2018-12-10', '2018-12-11', '2018-12-12',
#                '2018-12-13', '2018-12-14', '2018-12-15', '2018-12-16',
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-22', '2018-12-23', '2018-12-24',
#                '2018-12-25', '2018-12-26', '2018-12-27', '2018-12-28',
#                '2018-12-29', '2018-12-30', '2018-12-31', '2019-01-01',
#                '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-05',
#                '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09',
#                '2019-01-10', '2019-01-11', '2019-01-12', '2019-01-13',
#                '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17',
#                '2019-01-18', '2019-01-19', '2019-01-20', '2019-01-21',
# ...

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "http://movie.naver.com/" + \
                                    "movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=
                                   urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name,
                     'point':movie_point})
movie.head()
# Out:
#         date            name point
# 0 2018-12-01        보헤미안 랩소디  9.57
# 1 2018-12-01         베일리 어게인  9.55
# 2 2018-12-01      폴란드로 간 아이들  9.45
# 3 2018-12-01  번 더 스테이지: 더 무비  9.40
# 4 2018-12-01          울지마 톤즈  9.34

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4551 entries, 0 to 4550
# Data columns (total 3 columns):
# date     4551 non-null datetime64[ns]
# name     4551 non-null object
# point    4551 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 71.1+ KB

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# Out:
#                                                         point
# name
# 보헤미안 랩소디    9.579.579.579.579.569.569.569.569.559.559.549....
# 베일리 어게인     9.559.569.579.569.559.569.569.569.559.559.549....
# 헌터 킬러       9.539.519.529.529.529.549.549.479.469.459.459....
# 당갈          9.469.469.459.459.459.459.459.459.459.459.459....
# 폴란드로 간 아이들  9.459.469.479.479.459.459.469.469.449.459.459....

# %%
tmp = movie.query('name == ["보헤미안 랩소디"]')
tmp
# Out:
#            date      name point
# 0    2018-12-01  보헤미안 랩소디  9.57
# 34   2018-12-02  보헤미안 랩소디  9.57
# 69   2018-12-03  보헤미안 랩소디  9.57
# 101  2018-12-04  보헤미안 랩소디  9.57
# 143  2018-12-05  보헤미안 랩소디  9.56
# 190  2018-12-06  보헤미안 랩소디  9.56
# 238  2018-12-07  보헤미안 랩소디  9.56
# 288  2018-12-08  보헤미안 랩소디  9.56
# 337  2018-12-09  보헤미안 랩소디  9.55
# 388  2018-12-10  보헤미안 랩소디  9.55
# 437  2018-12-11  보헤미안 랩소디  9.54
# 487  2018-12-12  보헤미안 랩소디  9.54
# 537  2018-12-13  보헤미안 랩소디  9.54
# 589  2018-12-14  보헤미안 랩소디  9.54
# 639  2018-12-15  보헤미안 랩소디  9.53
# 688  2018-12-16  보헤미안 랩소디  9.53
# 738  2018-12-17  보헤미안 랩소디  9.52
# 788  2018-12-18  보헤미안 랩소디  9.52
# 838  2018-12-19  보헤미안 랩소디  9.52
# 888  2018-12-20  보헤미안 랩소디  9.52
# 938  2018-12-21  보헤미안 랩소디  9.52
# 988  2018-12-22  보헤미안 랩소디  9.51
# 1038 2018-12-23  보헤미안 랩소디  9.51
# 1088 2018-12-24  보헤미안 랩소디  9.51
# 1132 2018-12-25  보헤미안 랩소디  9.51
# 1177 2018-12-26  보헤미안 랩소디  9.51
# 1222 2018-12-27  보헤미안 랩소디  9.51
# 1267 2018-12-28  보헤미안 랩소디  9.51
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], values=['point'],
                            aggfunc = 'first')
movie_pivot.head()
# Out:
#                   point                                                    \
# name       7년-그들이 없는 언론 8월의 크리스마스 거미줄에 걸린 소녀 걸어도 걸어도 국가부도의 날 그랜드 부다페스트 호텔
# date
# 2018-12-01          NaN       NaN        NaN     NaN    8.43         8.37
# 2018-12-02          NaN       NaN        NaN     NaN    8.42         8.38
# 2018-12-03          NaN       NaN        NaN     NaN    8.40         8.38
# 2018-12-04          NaN      9.23       8.53     NaN    8.35         8.38
# 2018-12-05          NaN      9.23       8.56     NaN    8.33         8.38
#
#                                                                                \
# name       그렇게 아버지가 된다  그린치 극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~ 극장판 포켓몬스터 모두의 이야기
# date
# 2018-12-01         NaN  NaN                             NaN               NaN
# 2018-12-02         NaN  NaN                             NaN               NaN
# 2018-12-03         NaN  NaN                             NaN               NaN
# ...

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], values=['point'],
                            aggfunc = 'first')
movie.name
# Out:
# 0                              보헤미안 랩소디
# 1                               베일리 어게인
# 2                            폴란드로 간 아이들
# 3                        번 더 스테이지: 더 무비
# 4                                울지마 톤즈
# 5                                 어느 가족
# 6                     극장판 헬로카봇 : 백악기 시대
# 7                                    출국
# 8                                    바울
# 9                               스타 이즈 본
# 10                                  미쓰백
# 11                                타샤 튜더
# 12                        카메라를 멈추면 안 돼!
# 13                                패딩턴 2
# 14                                 보디가드
# 15                                   청설
# 16                               완벽한 타인
# 17                             워크 투 리멤버
# 18                              국가부도의 날
# 19                               팬텀 스레드
# 20                         그랜드 부다페스트 호텔
# 21                    셰이프 오브 워터: 사랑의 모양
# 22                         너의 췌장을 먹고 싶어
# ...

# %%
movie
# Out:
#            date                             name point
# 0    2018-12-01                         보헤미안 랩소디  9.57
# 1    2018-12-01                          베일리 어게인  9.55
# 2    2018-12-01                       폴란드로 간 아이들  9.45
# 3    2018-12-01                   번 더 스테이지: 더 무비  9.40
# 4    2018-12-01                           울지마 톤즈  9.34
# 5    2018-12-01                            어느 가족  9.23
# 6    2018-12-01                극장판 헬로카봇 : 백악기 시대  9.23
# 7    2018-12-01                               출국  9.20
# 8    2018-12-01                               바울  9.18
# 9    2018-12-01                          스타 이즈 본  9.16
# 10   2018-12-01                              미쓰백  9.14
# 11   2018-12-01                            타샤 튜더  9.13
# 12   2018-12-01                    카메라를 멈추면 안 돼!  9.12
# 13   2018-12-01                            패딩턴 2  9.11
# 14   2018-12-01                             보디가드  9.02
# 15   2018-12-01                               청설  9.01
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"

font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
movie.name[0]
# Out:
# '보헤미안 랩소디'

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], values=['point'],
                            aggfunc = 'first')

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie.name
# Out:
# 0                              보헤미안 랩소디
# 1                               베일리 어게인
# 2                            폴란드로 간 아이들
# 3                        번 더 스테이지: 더 무비
# 4                                울지마 톤즈
# 5                                 어느 가족
# 6                     극장판 헬로카봇 : 백악기 시대
# 7                                    출국
# 8                                    바울
# 9                               스타 이즈 본
# 10                                  미쓰백
# 11                                타샤 튜더
# 12                        카메라를 멈추면 안 돼!
# 13                                패딩턴 2
# 14                                 보디가드
# 15                                   청설
# 16                               완벽한 타인
# 17                             워크 투 리멤버
# 18                              국가부도의 날
# 19                               팬텀 스레드
# 20                         그랜드 부다페스트 호텔
# 21                    셰이프 오브 워터: 사랑의 모양
# 22                         너의 췌장을 먹고 싶어
# ...

# %%
import numpy as np

# %%
movie_pivot.columns[0]
# Out:
# '7년-그들이 없는 언론'

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], 
                                         values=['point'], aggfunc = 'first')
movie_pivot.head()
# Out:
#                   point                                                    \
# name       7년-그들이 없는 언론 8월의 크리스마스 거미줄에 걸린 소녀 걸어도 걸어도 국가부도의 날 그랜드 부다페스트 호텔
# date
# 2018-12-01          NaN       NaN        NaN     NaN    8.43         8.37
# 2018-12-02          NaN       NaN        NaN     NaN    8.42         8.38
# 2018-12-03          NaN       NaN        NaN     NaN    8.40         8.38
# 2018-12-04          NaN      9.23       8.53     NaN    8.35         8.38
# 2018-12-05          NaN      9.23       8.56     NaN    8.33         8.38
#
#                                                                                \
# name       그렇게 아버지가 된다  그린치 극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~ 극장판 포켓몬스터 모두의 이야기
# date
# 2018-12-01         NaN  NaN                             NaN               NaN
# 2018-12-02         NaN  NaN                             NaN               NaN
# 2018-12-03         NaN  NaN                             NaN               NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot
# Out:
# name       7년-그들이 없는 언론 8월의 크리스마스 거미줄에 걸린 소녀 걸어도 걸어도 국가부도의 날 그랜드 부다페스트 호텔  \
# date
# 2018-12-01          NaN       NaN        NaN     NaN    8.43         8.37
# 2018-12-02          NaN       NaN        NaN     NaN    8.42         8.38
# 2018-12-03          NaN       NaN        NaN     NaN    8.40         8.38
# 2018-12-04          NaN      9.23       8.53     NaN    8.35         8.38
# 2018-12-05          NaN      9.23       8.56     NaN    8.33         8.38
# 2018-12-06          NaN      9.23       8.56     NaN    8.33         8.38
# 2018-12-07          NaN      9.23       8.55     NaN    8.31         8.38
# 2018-12-08          NaN       NaN       8.56     NaN    8.32         8.38
# 2018-12-09          NaN       NaN       8.59     NaN    8.33         8.38
# 2018-12-10          NaN       NaN       8.60     NaN    8.33         8.38
# 2018-12-11          NaN       NaN       8.60     NaN    8.32          NaN
# 2018-12-12          NaN       NaN       8.61     NaN    8.32          NaN
# ...

# %%
plist = movie_pivot.columns

# %%
plist
# Out:
# Index([7년-그들이 없는 언론, 8월의 크리스마스, 거미줄에 걸린 소녀, 걸어도 걸어도, 국가부도의 날, 그랜드 부다페스트 호텔,
#        그렇게 아버지가 된다, 그린치, 극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~, 극장판 포켓몬스터 모두의 이야기,
#        ...
#        해피 투게더, 핵소 고지, 허스토리, 헌터 킬러, 헤이트풀8, 호두까기 인형과 4개의 왕국, 환상의 빛, 후드, 휘트니, 히트],
#       dtype='object', name='name', length=103)

# %%
j = 0
for i in plist:
    if i == '보헤미안 랩소디':
        print('발견')
        break
    j += 1
print(j)
# Out:
# 발견
# 38

# %%
plt.plot(movie_pivot['보헤미안 랩소디'])
plt.legend('보헤미안 랩소디', loc = 'best')
plt.grid()
plt.show()

# %%
plt.plot(movie_pivot['7년-그들이 없는 언론'])
plt.legend('7년-그들이 없는 언론', loc = 'best')
plt.grid()
plt.show()

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4551 entries, 0 to 4550
# Data columns (total 3 columns):
# date     4551 non-null datetime64[ns]
# name     4551 non-null object
# point    4551 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 88.9+ KB

# %%
type(movie['point'][0])
# Out:
# numpy.float64

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], 
                                         values=['point'], aggfunc = 'first')
movie_pivot.head()
# Out:
#                   point                                                    \
# name       7년-그들이 없는 언론 8월의 크리스마스 거미줄에 걸린 소녀 걸어도 걸어도 국가부도의 날 그랜드 부다페스트 호텔
# date
# 2018-12-01          NaN       NaN        NaN     NaN    8.43         8.37
# 2018-12-02          NaN       NaN        NaN     NaN    8.42         8.38
# 2018-12-03          NaN       NaN        NaN     NaN    8.40         8.38
# 2018-12-04          NaN      9.23       8.53     NaN    8.35         8.38
# 2018-12-05          NaN      9.23       8.56     NaN    8.33         8.38
#
#                                                                               \
# name       그렇게 아버지가 된다 그린치 극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~ 극장판 포켓몬스터 모두의 이야기
# date
# 2018-12-01         NaN NaN                             NaN               NaN
# 2018-12-02         NaN NaN                             NaN               NaN
# 2018-12-03         NaN NaN                             NaN               NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_name
# Out:
# ['보헤미안 랩소디',
#  '베일리 어게인',
#  '폴란드로 간 아이들',
#  '번 더 스테이지: 더 무비',
#  '울지마 톤즈',
#  '어느 가족',
#  '극장판 헬로카봇 : 백악기 시대',
#  '출국',
#  '바울',
#  '스타 이즈 본',
#  '미쓰백',
#  '타샤 튜더',
#  '카메라를 멈추면 안 돼!',
#  '패딩턴 2',
#  '보디가드',
#  '청설',
#  '완벽한 타인',
#  '워크 투 리멤버',
#  '국가부도의 날',
#  '팬텀 스레드',
#  '그랜드 부다페스트 호텔',
#  '셰이프 오브 워터: 사랑의 모양',
#  '너의 췌장을 먹고 싶어',
#  '칠드런 오브 맨',
#  '죄 많은 소녀',
#  '성난황소',
#  '후드',
#  '크레이지 리치 아시안',
#  '퍼스트맨',
#  '원더풀 고스트',
#  '신비한 동물들과 그린델왈드의 범죄',
#  '동네사람들',
#  '창궐',
#  '여곡성',
#  '보헤미안 랩소디',
#  '베일리 어게인',
#  '폴란드로 간 아이들',
#  '번 더 스테이지: 더 무비',
#  '울지마 톤즈',
#  '어느 가족',
#  '극장판 헬로카봇 : 백악기 시대',
#  '바울',
#  '스타 이즈 본',
#  '미쓰백',
#  '타샤 튜더',
#  '카메라를 멈추면 안 돼!',
#  '패딩턴 2',
#  '출국',
#  '보디가드',
#  '청설',
#  '완벽한 타인',
#  '워크 투 리멤버',
#  '국가부도의 날',
#  '팬텀 스레드',
#  '그랜드 부다페스트 호텔',
#  '셰이프 오브 워터: 사랑의 모양',
#  '너의 췌장을 먹고 싶어',
#  '칠드런 오브 맨',
#  '죄 많은 소녀',
#  '성난황소',
#  '후드',
#  '크레이지 리치 아시안',
#  '퍼스트맨',
#  '원더풀 고스트',
#  '신비한 동물들과 그린델왈드의 범죄',
#  '동네사람들',
#  '창궐',
#  '여곡성',
#  '베일리 어게인',
# ...

# %%
target_col = []
for i in range(0,5):
    target_col.append(movie_name[i])

# %%
plt.figure(figsize=(12,6))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.grid()
plt.show()
